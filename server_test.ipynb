# %%
import requests
import datetime
import time
from IPython.display import Image, display, clear_output
from base64 import b64decode

# Replace with your actual base64 string

start = datetime.datetime.now()
for i in range(200):
    response = requests.get("http://10.196.56.114:2000/image")
    base64_data = response.json()["base64"]

    # response2 = requests.get("http://10.196.56.114:2000/position")
    # position_data = response2.json()

    clear_output(wait=True)
    display(Image(b64decode(base64_data)))
    print(f"Frame: {i+1}/200")
    print(position_data)


finish = datetime.datetime.now()

print(finish-start)
print(response.json())
# Out:
# Frame: 1/200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      18     display(Image(b64decode(base64_data)))
#      19     print(f"Frame: {i+1}/200")
# ---> 20     print(position_data)
#      23 finish = datetime.datetime.now()
#      25 print(finish-start)
#
# NameError: name 'position_data' is not defined
